# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config4 import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("WeatherPy_vacation.csv")
vacation_df= vacation_df.loc[vacation_df['Country'] =='AU']
vacation_df
# Out:
#      City_ID           City Country  Max Temp Weather Description      Lat  \
# 9         38      Busselton      AU     57.09     overcast clouds -33.6500
# 34        90      Carnarvon      AU     64.47     overcast clouds -24.8667
# 66       162      Geraldton      AU     61.21     overcast clouds -28.7667
# 67       164      Byron Bay      AU     62.55          few clouds -28.6500
# 125      308      Nhulunbuy      AU     74.01           clear sky -12.2333
# 161      388   Port Hedland      AU     62.65          few clouds -20.3167
# 164      395        Yeppoon      AU     55.18           clear sky -23.1333
# 170      403     Nelson Bay      AU     55.99     overcast clouds -32.7167
# 197      483      Innisfail      AU     68.43     overcast clouds -17.5333
# 239      614         Mackay      AU     63.05           clear sky -21.1500
# 244      628       Karratha      AU     68.85       broken clouds -20.7377
# 254      652  Coffs Harbour      AU     59.13    scattered clouds -30.3000
# 266      677        Ballina      AU     55.78    scattered clouds -28.8667
#
#           Lng                                      Hotel Name
# 9    115.3333                         Observatory Guest House
# 34   113.6333                           Hospitality Carnarvon
# 66   114.6000                       Broadwater Mariner Resort
# 67   153.6167                    Backpackers Inn on the Beach
# 125  136.7667                         East Arnhem Real Estate
# 161  118.5667                             The Esplanade Hotel
# 164  150.7333                                Villa Mar Colina
# 170  152.1500                               Mantra Nelson Bay
# 197  146.0333                                 Moondarra Motel
# 239  149.2000                       International Lodge Motel
# 244  116.8463                            ibis Styles Karratha
# 254  153.1333                                   Aquajet Motel
# 266  153.5667  Ramada Hotel & Suites by Wyndham Ballina Byron

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Weather Description</dt><dd>{Weather Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]

# %%
# 4a. Add a marker layer for each city to the map.
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
# 4b. Display the figure
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.4)
fig.add_layer(marker_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.

vacation_start = vacation_df.loc[vacation_df['City'] == 'Byron Bay']
vacation_end = vacation_df.loc[vacation_df['City'] == 'Byron Bay']
vacation_stop1 = vacation_df.loc[vacation_df['City'] == 'Ballina']
vacation_stop2 = vacation_df.loc[vacation_df['City'] == 'Coffs Harbour'] 
vacation_stop3 = vacation_df.loc[vacation_df['City'] == 'Nelson Bay']

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
start = pd.DataFrame(vacation_start[["Lat", "Lng"]]).to_numpy()[0]
end = pd.DataFrame(vacation_end[["Lat", "Lng"]]).to_numpy()[0]
stop1 = pd.DataFrame(vacation_stop1[["Lat", "Lng"]]).to_numpy()[0]
stop2 = pd.DataFrame(vacation_stop2[["Lat", "Lng"]]).to_numpy()[0]
stop3 = pd.DataFrame(vacation_stop3[["Lat", "Lng"]]).to_numpy()[0]

print(start)
print(stop1)
print(stop2)
print(stop3)
print(end)
# Out:
# [-28.65   153.6167]
# [-28.8667 153.5667]
# [-30.3    153.1333]
# [-32.7167 152.15  ]
# [-28.65   153.6167]

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".
fig = gmaps.figure()
travel_route = gmaps.directions_layer(start, end, waypoints=[stop1,stop2,stop3], travel_mode="DRIVING")
fig.add_layer(travel_route)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
itinerary_df = pd.concat([vacation_start, vacation_stop1, 
                          vacation_stop2, vacation_stop3]
                         ,ignore_index=True)
itinerary_df
# Out:
#    City_ID           City Country  Max Temp Weather Description      Lat  \
# 0      164      Byron Bay      AU     62.55          few clouds -28.6500
# 1      677        Ballina      AU     55.78    scattered clouds -28.8667
# 2      652  Coffs Harbour      AU     59.13    scattered clouds -30.3000
# 3      403     Nelson Bay      AU     55.99     overcast clouds -32.7167
#
#         Lng                                      Hotel Name
# 0  153.6167                    Backpackers Inn on the Beach
# 1  153.5667  Ramada Hotel & Suites by Wyndham Ballina Byron
# 2  153.1333                                   Aquajet Motel
# 3  152.1500                               Mantra Nelson Bay

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Weather Description</dt><dd>{Weather Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]

locations
# Out:
#        Lat       Lng
# 0 -28.6500  153.6167
# 1 -28.8667  153.5667
# 2 -30.3000  153.1333
# 3 -32.7167  152.1500

# %%
# 11a. Add a marker layer for each city to the map.
fig = gmaps.figure()
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)
# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
