# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
#import citipy 6.1.5
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = list()
for coord in coordinates:
    cities_name = citipy.nearest_city(coord[0],coord[1]).city_name
    if cities_name not in cities:
        cities.append(cities_name)
print(cities[:10], 'Generate', len(cities))
# Out:
# ['georgetown', 'katsiveli', 'mataura', 'port-cartier', 'hobart', 'barrow', 'ushuaia', 'conselheiro pena', 'touros', 'mattoon'] Generate 749

# %%
#getting url and key to get data from API
# Import the requests library.
import requests

# Import the API key.
from config1 import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# initial counters for log and sets
record_count = 1 
set_count = 1

city_data = list()
basic_url = "http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=" + weather_api_key

print('Beginning Data Retrieval     ')
print("-----------------------------")

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i != 0):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count +=1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_name = city
        city_country = city_weather["sys"]["country"]
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_description = city_weather['weather'][0]['description']
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Date": city_date, 
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          'Weather Description':city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | georgetown
# Processing Record 2 of Set 1 | katsiveli
# City not found. Skipping...
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | port-cartier
# Processing Record 5 of Set 1 | hobart
# Processing Record 6 of Set 1 | barrow
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | conselheiro pena
# Processing Record 9 of Set 1 | touros
# Processing Record 10 of Set 1 | mattoon
# Processing Record 11 of Set 1 | meadow lake
# Processing Record 12 of Set 1 | lalmohan
# Processing Record 13 of Set 1 | punta arenas
# Processing Record 14 of Set 1 | sioux lookout
# Processing Record 15 of Set 1 | faanui
# Processing Record 16 of Set 1 | portland
# Processing Record 17 of Set 1 | upernavik
# Processing Record 18 of Set 1 | andenes
# Processing Record 19 of Set 1 | kavaratti
# Processing Record 20 of Set 1 | bluff
# Processing Record 21 of Set 1 | bethel
# Processing Record 22 of Set 1 | ilulissat
# Processing Record 23 of Set 1 | avarua
# Processing Record 24 of Set 1 | provideniya
# Processing Record 25 of Set 1 | verkhnyaya inta
# Processing Record 26 of Set 1 | mahajanga
# Processing Record 27 of Set 1 | ostrovnoy
# Processing Record 28 of Set 1 | ambilobe
# Processing Record 29 of Set 1 | houma
# Processing Record 30 of Set 1 | leningradskiy
# Processing Record 31 of Set 1 | khatanga
# Processing Record 32 of Set 1 | mahebourg
# Processing Record 33 of Set 1 | morondava
# Processing Record 34 of Set 1 | jamestown
# Processing Record 35 of Set 1 | bangor
# Processing Record 36 of Set 1 | chokurdakh
# Processing Record 37 of Set 1 | havoysund
# Processing Record 38 of Set 1 | jibuti
# Processing Record 39 of Set 1 | izvestkovyy
# Processing Record 40 of Set 1 | busselton
# Processing Record 41 of Set 1 | saint-philippe
# Processing Record 42 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 43 of Set 1 | martapura
# Processing Record 44 of Set 1 | vaini
# Processing Record 45 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 46 of Set 1 | hasaki
# Processing Record 47 of Set 1 | svetlaya
# Processing Record 48 of Set 1 | port alfred
# Processing Record 49 of Set 1 | piedras negras
# Processing Record 50 of Set 1 | poum
# Processing Record 1 of Set 2 | tshela
# Processing Record 2 of Set 2 | aksarka
# Processing Record 3 of Set 2 | wladyslawowo
# Processing Record 4 of Set 2 | beringovskiy
# Processing Record 5 of Set 2 | port elizabeth
# Processing Record 6 of Set 2 | airai
# Processing Record 7 of Set 2 | plouzane
# Processing Record 8 of Set 2 | zlynka
# Processing Record 9 of Set 2 | new norfolk
# Processing Record 10 of Set 2 | vera cruz
# Processing Record 11 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 12 of Set 2 | ranikhet
# Processing Record 13 of Set 2 | aras
# Processing Record 14 of Set 2 | guerrero negro
# Processing Record 15 of Set 2 | cidreira
# Processing Record 16 of Set 2 | kodinsk
# Processing Record 17 of Set 2 | victoria
# Processing Record 18 of Set 2 | hithadhoo
# Processing Record 19 of Set 2 | isangel
# Processing Record 20 of Set 2 | vila velha
# Processing Record 21 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 2 | luocheng
# Processing Record 23 of Set 2 | lerik
# Processing Record 24 of Set 2 | hermanus
# Processing Record 25 of Set 2 | chicama
# Processing Record 26 of Set 2 | sarakhs
# Processing Record 27 of Set 2 | mar del plata
# Processing Record 28 of Set 2 | rikitea
# Processing Record 29 of Set 2 | coquimbo
# Processing Record 30 of Set 2 | torbay
# Processing Record 31 of Set 2 | perevolotskiy
# Processing Record 32 of Set 2 | narsaq
# Processing Record 33 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 34 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 35 of Set 2 | ladario
# Processing Record 36 of Set 2 | lebu
# Processing Record 37 of Set 2 | tonder
# Processing Record 38 of Set 2 | norman wells
# Processing Record 39 of Set 2 | bergen
# Processing Record 40 of Set 2 | kyabe
# Processing Record 41 of Set 2 | san patricio
# Processing Record 42 of Set 2 | loviisa
# Processing Record 43 of Set 2 | ushtobe
# Processing Record 44 of Set 2 | kapaa
# Processing Record 45 of Set 2 | peniche
# Processing Record 46 of Set 2 | butaritari
# Processing Record 47 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 48 of Set 2 | yellowknife
# Processing Record 49 of Set 2 | carnarvon
# Processing Record 50 of Set 2 | yar-sale
# Processing Record 1 of Set 3 | te anau
# Processing Record 2 of Set 3 | poso
# Processing Record 3 of Set 3 | joshimath
# Processing Record 4 of Set 3 | duluth
# Processing Record 5 of Set 3 | cherskiy
# Processing Record 6 of Set 3 | half moon bay
# Processing Record 7 of Set 3 | bouca
# Processing Record 8 of Set 3 | derzhavinsk
# Processing Record 9 of Set 3 | riviere-au-renard
# Processing Record 10 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 11 of Set 3 | kodiak
# Processing Record 12 of Set 3 | albany
# Processing Record 13 of Set 3 | clacton-on-sea
# Processing Record 14 of Set 3 | bama
# Processing Record 15 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 3 | seoul
# Processing Record 17 of Set 3 | garowe
# Processing Record 18 of Set 3 | puerto ayora
# Processing Record 19 of Set 3 | okha
# Processing Record 20 of Set 3 | tuktoyaktuk
# Processing Record 21 of Set 3 | dikson
# Processing Record 22 of Set 3 | chuy
# Processing Record 23 of Set 3 | ust-nera
# Processing Record 24 of Set 3 | boa vista
# Processing Record 25 of Set 3 | brae
# Processing Record 26 of Set 3 | aklavik
# Processing Record 27 of Set 3 | hilo
# Processing Record 28 of Set 3 | la paz
# Processing Record 29 of Set 3 | adrar
# Processing Record 30 of Set 3 | qaanaaq
# Processing Record 31 of Set 3 | hualmay
# Processing Record 32 of Set 3 | kharp
# Processing Record 33 of Set 3 | esfahan
# Processing Record 34 of Set 3 | segou
# Processing Record 35 of Set 3 | waingapu
# Processing Record 36 of Set 3 | bilma
# Processing Record 37 of Set 3 | cape town
# Processing Record 38 of Set 3 | ancud
# Processing Record 39 of Set 3 | cabo san lucas
# Processing Record 40 of Set 3 | rock sound
# Processing Record 41 of Set 3 | atuona
# Processing Record 42 of Set 3 | castro
# Processing Record 43 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 44 of Set 3 | chiang mai
# Processing Record 45 of Set 3 | kununurra
# Processing Record 46 of Set 3 | mount gambier
# Processing Record 47 of Set 3 | severo-kurilsk
# Processing Record 48 of Set 3 | grand island
# Processing Record 49 of Set 3 | coihaique
# Processing Record 50 of Set 3 | muros
# Processing Record 1 of Set 4 | bambous virieux
# Processing Record 2 of Set 4 | zeya
# Processing Record 3 of Set 4 | lembang
# Processing Record 4 of Set 4 | komsomolskiy
# Processing Record 5 of Set 4 | morro bay
# Processing Record 6 of Set 4 | mount isa
# Processing Record 7 of Set 4 | opuwo
# Processing Record 8 of Set 4 | quatre cocos
# Processing Record 9 of Set 4 | bredasdorp
# Processing Record 10 of Set 4 | saldanha
# Processing Record 11 of Set 4 | broome
# Processing Record 12 of Set 4 | klaksvik
# Processing Record 13 of Set 4 | cibitoke
# Processing Record 14 of Set 4 | safaga
# Processing Record 15 of Set 4 | flin flon
# Processing Record 16 of Set 4 | east london
# Processing Record 17 of Set 4 | ixtapa
# Processing Record 18 of Set 4 | zhigansk
# Processing Record 19 of Set 4 | zarate
# Processing Record 20 of Set 4 | burgersdorp
# Processing Record 21 of Set 4 | saint-augustin
# Processing Record 22 of Set 4 | launceston
# Processing Record 23 of Set 4 | ribeira grande
# Processing Record 24 of Set 4 | geraldton
# Processing Record 25 of Set 4 | clyde river
# Processing Record 26 of Set 4 | byron bay
# Processing Record 27 of Set 4 | vila franca do campo
# Processing Record 28 of Set 4 | malakal
# Processing Record 29 of Set 4 | yulara
# Processing Record 30 of Set 4 | esperance
# Processing Record 31 of Set 4 | nikolskoye
# Processing Record 32 of Set 4 | tasiilaq
# Processing Record 33 of Set 4 | sheboygan
# Processing Record 34 of Set 4 | vidim
# Processing Record 35 of Set 4 | westport
# Processing Record 36 of Set 4 | barra do corda
# Processing Record 37 of Set 4 | voh
# Processing Record 38 of Set 4 | banda aceh
# Processing Record 39 of Set 4 | kemijarvi
# Processing Record 40 of Set 4 | fortuna
# Processing Record 41 of Set 4 | kulykiv
# Processing Record 42 of Set 4 | labutta
# City not found. Skipping...
# Processing Record 43 of Set 4 | tiksi
# Processing Record 44 of Set 4 | kijang
# Processing Record 45 of Set 4 | elizabeth city
# Processing Record 46 of Set 4 | saint-francois
# Processing Record 47 of Set 4 | monte patria
# Processing Record 48 of Set 4 | saint-paul
# Processing Record 49 of Set 4 | pochutla
# Processing Record 50 of Set 4 | sosva
# Processing Record 1 of Set 5 | cabras
# Processing Record 2 of Set 5 | vila
# Processing Record 3 of Set 5 | longyearbyen
# Processing Record 4 of Set 5 | carson city
# Processing Record 5 of Set 5 | kavieng
# Processing Record 6 of Set 5 | svay rieng
# Processing Record 7 of Set 5 | sabang
# Processing Record 8 of Set 5 | fevralsk
# City not found. Skipping...
# Processing Record 9 of Set 5 | cervo
# Processing Record 10 of Set 5 | pevek
# Processing Record 11 of Set 5 | siguiri
# Processing Record 12 of Set 5 | oksfjord
# Processing Record 13 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 14 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 15 of Set 5 | iranshahr
# Processing Record 16 of Set 5 | pangody
# Processing Record 17 of Set 5 | nanortalik
# Processing Record 18 of Set 5 | kruisfontein
# Processing Record 19 of Set 5 | sinkat
# City not found. Skipping...
# Processing Record 20 of Set 5 | san cristobal
# Processing Record 21 of Set 5 | sumbe
# Processing Record 22 of Set 5 | thompson
# Processing Record 23 of Set 5 | karakendzha
# City not found. Skipping...
# Processing Record 24 of Set 5 | dingle
# Processing Record 25 of Set 5 | henties bay
# Processing Record 26 of Set 5 | namibe
# Processing Record 27 of Set 5 | souillac
# Processing Record 28 of Set 5 | akonolinga
# Processing Record 29 of Set 5 | namie
# Processing Record 30 of Set 5 | athabasca
# Processing Record 31 of Set 5 | pokhara
# Processing Record 32 of Set 5 | pangnirtung
# Processing Record 33 of Set 5 | boca do acre
# Processing Record 34 of Set 5 | iqaluit
# Processing Record 35 of Set 5 | puerto baquerizo moreno
# Processing Record 36 of Set 5 | arraial do cabo
# Processing Record 37 of Set 5 | san jose
# Processing Record 38 of Set 5 | hobyo
# Processing Record 39 of Set 5 | luderitz
# Processing Record 40 of Set 5 | ginir
# Processing Record 41 of Set 5 | puerto palomas
# Processing Record 42 of Set 5 | katsuura
# Processing Record 43 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 44 of Set 5 | laguna
# Processing Record 45 of Set 5 | manggar
# Processing Record 46 of Set 5 | mrirt
# City not found. Skipping...
# Processing Record 47 of Set 5 | tilichiki
# Processing Record 48 of Set 5 | kaitangata
# Processing Record 49 of Set 5 | kahului
# Processing Record 50 of Set 5 | port lincoln
# Processing Record 1 of Set 6 | guiong
# Processing Record 2 of Set 6 | galiwinku
# City not found. Skipping...
# Processing Record 3 of Set 6 | jasper
# Processing Record 4 of Set 6 | praxedis guerrero
# Processing Record 5 of Set 6 | bontang
# Processing Record 6 of Set 6 | hambantota
# Processing Record 7 of Set 6 | harper
# Processing Record 8 of Set 6 | lysyanka
# Processing Record 9 of Set 6 | alofi
# Processing Record 10 of Set 6 | bournemouth
# Processing Record 11 of Set 6 | san rafael
# Processing Record 12 of Set 6 | bengkulu
# Processing Record 13 of Set 6 | ayna
# Processing Record 14 of Set 6 | fairbanks
# Processing Record 15 of Set 6 | zhangye
# Processing Record 16 of Set 6 | burgeo
# Processing Record 17 of Set 6 | fukue
# Processing Record 18 of Set 6 | hofn
# Processing Record 19 of Set 6 | molteno
# Processing Record 20 of Set 6 | boyolangu
# Processing Record 21 of Set 6 | ulagan
# Processing Record 22 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 23 of Set 6 | ahipara
# Processing Record 24 of Set 6 | knysna
# Processing Record 25 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 6 | colares
# Processing Record 27 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 28 of Set 6 | kumba
# Processing Record 29 of Set 6 | sinjar
# Processing Record 30 of Set 6 | talcahuano
# Processing Record 31 of Set 6 | kushima
# Processing Record 32 of Set 6 | mormugao
# Processing Record 33 of Set 6 | cockburn town
# Processing Record 34 of Set 6 | praia
# Processing Record 35 of Set 6 | bloemfontein
# Processing Record 36 of Set 6 | san quintin
# Processing Record 37 of Set 6 | yumaguzino
# Processing Record 38 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 39 of Set 6 | raahe
# Processing Record 40 of Set 6 | qui nhon
# Processing Record 41 of Set 6 | jiayuguan
# Processing Record 42 of Set 6 | vestmannaeyjar
# Processing Record 43 of Set 6 | lata
# Processing Record 44 of Set 6 | nueve de julio
# Processing Record 45 of Set 6 | puerto madero
# Processing Record 46 of Set 6 | kardamas
# Processing Record 47 of Set 6 | kouango
# Processing Record 48 of Set 6 | mayumba
# Processing Record 49 of Set 6 | comodoro rivadavia
# Processing Record 50 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 1 of Set 7 | borodyanka
# Processing Record 2 of Set 7 | challapata
# Processing Record 3 of Set 7 | shcholkine
# City not found. Skipping...
# Processing Record 4 of Set 7 | noumea
# Processing Record 5 of Set 7 | lichuan
# Processing Record 6 of Set 7 | porto santo
# Processing Record 7 of Set 7 | suwannaphum
# Processing Record 8 of Set 7 | bathsheba
# Processing Record 9 of Set 7 | wildberg
# Processing Record 10 of Set 7 | bingol
# Processing Record 11 of Set 7 | san vicente
# Processing Record 12 of Set 7 | lamu
# Processing Record 13 of Set 7 | lagoa
# Processing Record 14 of Set 7 | shellbrook
# Processing Record 15 of Set 7 | kangaatsiaq
# Processing Record 16 of Set 7 | auki
# Processing Record 17 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 18 of Set 7 | zomin
# Processing Record 19 of Set 7 | azuaga
# Processing Record 20 of Set 7 | lavrentiya
# Processing Record 21 of Set 7 | emba
# Processing Record 22 of Set 7 | bull savanna
# Processing Record 23 of Set 7 | coahuayana
# Processing Record 24 of Set 7 | tarudant
# City not found. Skipping...
# Processing Record 25 of Set 7 | nizhniy baskunchak
# Processing Record 26 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 27 of Set 7 | kloulklubed
# Processing Record 28 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 29 of Set 7 | camacha
# Processing Record 30 of Set 7 | tongchuan
# Processing Record 31 of Set 7 | eregli
# Processing Record 32 of Set 7 | saskylakh
# Processing Record 33 of Set 7 | oktyabrskoye
# Processing Record 34 of Set 7 | mehamn
# Processing Record 35 of Set 7 | omsukchan
# Processing Record 36 of Set 7 | greenfield
# Processing Record 37 of Set 7 | ketchikan
# Processing Record 38 of Set 7 | buenavista
# Processing Record 39 of Set 7 | nhulunbuy
# Processing Record 40 of Set 7 | husavik
# Processing Record 41 of Set 7 | sibolga
# Processing Record 42 of Set 7 | chardara
# Processing Record 43 of Set 7 | manta
# Processing Record 44 of Set 7 | jinchang
# Processing Record 45 of Set 7 | inhambane
# Processing Record 46 of Set 7 | santa cruz
# Processing Record 47 of Set 7 | acari
# Processing Record 48 of Set 7 | necochea
# Processing Record 49 of Set 7 | krasnoselkup
# Processing Record 50 of Set 7 | caucaia
# Processing Record 1 of Set 8 | ternate
# Processing Record 2 of Set 8 | tamboril
# Processing Record 3 of Set 8 | san andres
# Processing Record 4 of Set 8 | tete
# Processing Record 5 of Set 8 | gorontalo
# Processing Record 6 of Set 8 | west helena
# Processing Record 7 of Set 8 | mookane
# Processing Record 8 of Set 8 | khor
# Processing Record 9 of Set 8 | hovd
# Processing Record 10 of Set 8 | korla
# Processing Record 11 of Set 8 | acapulco
# Processing Record 12 of Set 8 | srivardhan
# Processing Record 13 of Set 8 | praia da vitoria
# Processing Record 14 of Set 8 | vostok
# Processing Record 15 of Set 8 | baneh
# Processing Record 16 of Set 8 | tunduru
# City not found. Skipping...
# Processing Record 17 of Set 8 | kirensk
# Processing Record 18 of Set 8 | puerto escondido
# Processing Record 19 of Set 8 | sfantu gheorghe
# Processing Record 20 of Set 8 | sulangan
# Processing Record 21 of Set 8 | teya
# Processing Record 22 of Set 8 | sahrak
# City not found. Skipping...
# Processing Record 23 of Set 8 | wahpeton
# Processing Record 24 of Set 8 | salina cruz
# Processing Record 25 of Set 8 | ardahan
# Processing Record 26 of Set 8 | zhob
# Processing Record 27 of Set 8 | vardo
# Processing Record 28 of Set 8 | ust-omchug
# Processing Record 29 of Set 8 | arkhangelos
# City not found. Skipping...
# Processing Record 30 of Set 8 | leh
# Processing Record 31 of Set 8 | sitka
# Processing Record 32 of Set 8 | paamiut
# Processing Record 33 of Set 8 | krasnyy oktyabr
# Processing Record 34 of Set 8 | igarka
# Processing Record 35 of Set 8 | broken hill
# Processing Record 36 of Set 8 | manzhouli
# Processing Record 37 of Set 8 | prince rupert
# Processing Record 38 of Set 8 | tianpeng
# Processing Record 39 of Set 8 | bambanglipuro
# Processing Record 40 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 41 of Set 8 | marawi
# Processing Record 42 of Set 8 | beisfjord
# Processing Record 43 of Set 8 | mbandaka
# Processing Record 44 of Set 8 | chalus
# Processing Record 45 of Set 8 | svelgen
# Processing Record 46 of Set 8 | monte carmelo
# Processing Record 47 of Set 8 | rudbar
# Processing Record 48 of Set 8 | uwayl
# City not found. Skipping...
# Processing Record 49 of Set 8 | alexandria
# Processing Record 50 of Set 8 | miandrivazo
# Processing Record 1 of Set 9 | wuwei
# Processing Record 2 of Set 9 | kudahuvadhoo
# Processing Record 3 of Set 9 | ponta do sol
# Processing Record 4 of Set 9 | montecristo
# Processing Record 5 of Set 9 | devonport
# Processing Record 6 of Set 9 | shenjiamen
# Processing Record 7 of Set 9 | sonqor
# Processing Record 8 of Set 9 | boueni
# Processing Record 9 of Set 9 | luis correia
# Processing Record 10 of Set 9 | farah
# Processing Record 11 of Set 9 | analipsis
# Processing Record 12 of Set 9 | nsanje
# Processing Record 13 of Set 9 | tual
# Processing Record 14 of Set 9 | bereda
# Processing Record 15 of Set 9 | kontagora
# Processing Record 16 of Set 9 | toamasina
# Processing Record 17 of Set 9 | stettler
# Processing Record 18 of Set 9 | faya
# Processing Record 19 of Set 9 | oriximina
# Processing Record 20 of Set 9 | ponta delgada
# Processing Record 21 of Set 9 | hirara
# Processing Record 22 of Set 9 | avera
# Processing Record 23 of Set 9 | santa lucia
# Processing Record 24 of Set 9 | port hedland
# Processing Record 25 of Set 9 | itarema
# Processing Record 26 of Set 9 | majene
# Processing Record 27 of Set 9 | beloha
# Processing Record 28 of Set 9 | florianopolis
# Processing Record 29 of Set 9 | hanna
# Processing Record 30 of Set 9 | almenara
# Processing Record 31 of Set 9 | yeppoon
# Processing Record 32 of Set 9 | lotung
# City not found. Skipping...
# Processing Record 33 of Set 9 | mocambique
# City not found. Skipping...
# Processing Record 34 of Set 9 | sisimiut
# Processing Record 35 of Set 9 | micheweni
# Processing Record 36 of Set 9 | stolin
# Processing Record 37 of Set 9 | kisangani
# Processing Record 38 of Set 9 | likasi
# Processing Record 39 of Set 9 | taltal
# Processing Record 40 of Set 9 | scarborough
# Processing Record 41 of Set 9 | nelson bay
# Processing Record 42 of Set 9 | belmonte
# Processing Record 43 of Set 9 | kovur
# Processing Record 44 of Set 9 | burica
# City not found. Skipping...
# Processing Record 45 of Set 9 | zolotinka
# City not found. Skipping...
# Processing Record 46 of Set 9 | blythe
# Processing Record 47 of Set 9 | namatanai
# Processing Record 48 of Set 9 | ambovombe
# Processing Record 49 of Set 9 | brodokalmak
# Processing Record 50 of Set 9 | qaqortoq
# Processing Record 1 of Set 10 | altamira
# Processing Record 2 of Set 10 | bloomfield
# Processing Record 3 of Set 10 | sidi ali
# Processing Record 4 of Set 10 | morant bay
# Processing Record 5 of Set 10 | sikandra rao
# Processing Record 6 of Set 10 | adre
# Processing Record 7 of Set 10 | nago
# Processing Record 8 of Set 10 | cam ranh
# Processing Record 9 of Set 10 | sabha
# Processing Record 10 of Set 10 | high rock
# Processing Record 11 of Set 10 | baglung
# Processing Record 12 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 13 of Set 10 | toftir
# City not found. Skipping...
# Processing Record 14 of Set 10 | lulea
# Processing Record 15 of Set 10 | mujiayingzi
# Processing Record 16 of Set 10 | quchan
# Processing Record 17 of Set 10 | hamilton
# Processing Record 18 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 19 of Set 10 | vuktyl
# Processing Record 20 of Set 10 | wadi maliz
# Processing Record 21 of Set 10 | maldonado
# Processing Record 22 of Set 10 | faranah
# Processing Record 23 of Set 10 | salvador
# Processing Record 24 of Set 10 | talnakh
# Processing Record 25 of Set 10 | inongo
# Processing Record 26 of Set 10 | ust-maya
# Processing Record 27 of Set 10 | cayenne
# Processing Record 28 of Set 10 | gat
# Processing Record 29 of Set 10 | halifax
# Processing Record 30 of Set 10 | bolshaya sosnova
# Processing Record 31 of Set 10 | artyk
# City not found. Skipping...
# Processing Record 32 of Set 10 | aykhal
# Processing Record 33 of Set 10 | ornskoldsvik
# Processing Record 34 of Set 10 | pangai
# Processing Record 35 of Set 10 | tautira
# Processing Record 36 of Set 10 | kismayo
# Processing Record 37 of Set 10 | imeni poliny osipenko
# Processing Record 38 of Set 10 | waipawa
# Processing Record 39 of Set 10 | zhanatas
# City not found. Skipping...
# Processing Record 40 of Set 10 | ijaki
# City not found. Skipping...
# Processing Record 41 of Set 10 | kholodnyy
# Processing Record 42 of Set 10 | sechura
# Processing Record 43 of Set 10 | itoman
# Processing Record 44 of Set 10 | venice
# Processing Record 45 of Set 10 | port blair
# Processing Record 46 of Set 10 | lipin bor
# Processing Record 47 of Set 10 | torquay
# Processing Record 48 of Set 10 | lagos
# Processing Record 49 of Set 10 | ambanja
# Processing Record 50 of Set 10 | peoria
# Processing Record 1 of Set 11 | sao filipe
# Processing Record 2 of Set 11 | mushie
# Processing Record 3 of Set 11 | nyurba
# Processing Record 4 of Set 11 | kaele
# Processing Record 5 of Set 11 | saint-joseph
# Processing Record 6 of Set 11 | madison heights
# Processing Record 7 of Set 11 | saint george
# Processing Record 8 of Set 11 | sao joao da barra
# Processing Record 9 of Set 11 | yaan
# Processing Record 10 of Set 11 | bat yam
# Processing Record 11 of Set 11 | belyy yar
# Processing Record 12 of Set 11 | tezu
# Processing Record 13 of Set 11 | deputatskiy
# Processing Record 14 of Set 11 | palmas
# Processing Record 15 of Set 11 | begoro
# Processing Record 16 of Set 11 | karamea
# City not found. Skipping...
# Processing Record 17 of Set 11 | lompoc
# Processing Record 18 of Set 11 | kokoda
# Processing Record 19 of Set 11 | sikar
# Processing Record 20 of Set 11 | shubarshi
# Processing Record 21 of Set 11 | patacamaya
# Processing Record 22 of Set 11 | dwarka
# Processing Record 23 of Set 11 | margate
# Processing Record 24 of Set 11 | chapais
# Processing Record 25 of Set 11 | kalmunai
# Processing Record 26 of Set 11 | piterka
# Processing Record 27 of Set 11 | ati
# Processing Record 28 of Set 11 | penzance
# Processing Record 29 of Set 11 | tankara
# Processing Record 30 of Set 11 | innisfail
# Processing Record 31 of Set 11 | canaries
# Processing Record 32 of Set 11 | lingao
# Processing Record 33 of Set 11 | nador
# Processing Record 34 of Set 11 | nuuk
# Processing Record 35 of Set 11 | dabakala
# Processing Record 36 of Set 11 | konskie
# Processing Record 37 of Set 11 | honiara
# Processing Record 38 of Set 11 | axim
# Processing Record 39 of Set 11 | el cobre
# Processing Record 40 of Set 11 | san policarpo
# Processing Record 41 of Set 11 | santa fe
# Processing Record 42 of Set 11 | antiguo morelos
# Processing Record 43 of Set 11 | afmadu
# City not found. Skipping...
# Processing Record 44 of Set 11 | mwinilunga
# Processing Record 45 of Set 11 | juba
# Processing Record 46 of Set 11 | bud
# Processing Record 47 of Set 11 | ossora
# Processing Record 48 of Set 11 | polunochnoye
# Processing Record 49 of Set 11 | tawkar
# City not found. Skipping...
# Processing Record 50 of Set 11 | thatta
# Processing Record 1 of Set 12 | kalangala
# Processing Record 2 of Set 12 | hanstholm
# Processing Record 3 of Set 12 | grand gaube
# Processing Record 4 of Set 12 | makubetsu
# Processing Record 5 of Set 12 | saravan
# Processing Record 6 of Set 12 | naze
# Processing Record 7 of Set 12 | pacifica
# Processing Record 8 of Set 12 | galle
# Processing Record 9 of Set 12 | ewa beach
# Processing Record 10 of Set 12 | benghazi
# Processing Record 11 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 12 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 13 of Set 12 | fort saint james
# Processing Record 14 of Set 12 | kamarai
# Processing Record 15 of Set 12 | batemans bay
# Processing Record 16 of Set 12 | makarov
# Processing Record 17 of Set 12 | reconquista
# Processing Record 18 of Set 12 | akyab
# Processing Record 19 of Set 12 | luba
# Processing Record 20 of Set 12 | bhum
# Processing Record 21 of Set 12 | dakar
# Processing Record 22 of Set 12 | pyapon
# Processing Record 23 of Set 12 | toyooka
# Processing Record 24 of Set 12 | amudat
# Processing Record 25 of Set 12 | jalu
# Processing Record 26 of Set 12 | prado
# Processing Record 27 of Set 12 | jonava
# Processing Record 28 of Set 12 | tura
# Processing Record 29 of Set 12 | poroszlo
# Processing Record 30 of Set 12 | nouadhibou
# Processing Record 31 of Set 12 | pacific grove
# Processing Record 32 of Set 12 | minab
# Processing Record 33 of Set 12 | ciudad bolivar
# Processing Record 34 of Set 12 | puerto suarez
# Processing Record 35 of Set 12 | redmond
# Processing Record 36 of Set 12 | rawson
# Processing Record 37 of Set 12 | mogadishu
# Processing Record 38 of Set 12 | sao gotardo
# Processing Record 39 of Set 12 | buala
# Processing Record 40 of Set 12 | dakoro
# Processing Record 41 of Set 12 | yukhnov
# Processing Record 42 of Set 12 | dharampuri
# Processing Record 43 of Set 12 | larap
# Processing Record 44 of Set 12 | havre
# Processing Record 45 of Set 12 | bela vista
# Processing Record 46 of Set 12 | kutum
# Processing Record 47 of Set 12 | mpika
# Processing Record 48 of Set 12 | garissa
# Processing Record 49 of Set 12 | sakaiminato
# Processing Record 50 of Set 12 | monrovia
# Processing Record 1 of Set 13 | goryachegorsk
# Processing Record 2 of Set 13 | sonda
# Processing Record 3 of Set 13 | parabel
# Processing Record 4 of Set 13 | zabid
# Processing Record 5 of Set 13 | iseyin
# Processing Record 6 of Set 13 | kichera
# Processing Record 7 of Set 13 | tuatapere
# Processing Record 8 of Set 13 | humaita
# Processing Record 9 of Set 13 | lorengau
# Processing Record 10 of Set 13 | pozo colorado
# Processing Record 11 of Set 13 | vestmanna
# Processing Record 12 of Set 13 | ligatne
# Processing Record 13 of Set 13 | dodge city
# Processing Record 14 of Set 13 | manyana
# Processing Record 15 of Set 13 | fershampenuaz
# Processing Record 16 of Set 13 | bosaso
# Processing Record 17 of Set 13 | saint-louis
# Processing Record 18 of Set 13 | japura
# Processing Record 19 of Set 13 | zephyrhills
# Processing Record 20 of Set 13 | xichang
# Processing Record 21 of Set 13 | benguela
# Processing Record 22 of Set 13 | ondorhaan
# City not found. Skipping...
# Processing Record 23 of Set 13 | bozoum
# Processing Record 24 of Set 13 | acajutla
# Processing Record 25 of Set 13 | makungu
# Processing Record 26 of Set 13 | zhangzhou
# Processing Record 27 of Set 13 | vondrozo
# Processing Record 28 of Set 13 | solnechnyy
# Processing Record 29 of Set 13 | saint anthony
# Processing Record 30 of Set 13 | polovinnoye
# Processing Record 31 of Set 13 | khani
# Processing Record 32 of Set 13 | anloga
# Processing Record 33 of Set 13 | le port
# Processing Record 34 of Set 13 | manono
# Processing Record 35 of Set 13 | nemuro
# Processing Record 36 of Set 13 | xiantao
# Processing Record 37 of Set 13 | capitao poco
# Processing Record 38 of Set 13 | nabire
# Processing Record 39 of Set 13 | tocopilla
# Processing Record 40 of Set 13 | ilebo
# Processing Record 41 of Set 13 | forbes
# Processing Record 42 of Set 13 | catuday
# Processing Record 43 of Set 13 | gunjur
# Processing Record 44 of Set 13 | roald
# Processing Record 45 of Set 13 | sola
# Processing Record 46 of Set 13 | sur
# Processing Record 47 of Set 13 | mitchell
# Processing Record 48 of Set 13 | arlit
# Processing Record 49 of Set 13 | kathu
# Processing Record 50 of Set 13 | kailua
# Processing Record 1 of Set 14 | casa quemada
# Processing Record 2 of Set 14 | mananara
# Processing Record 3 of Set 14 | porto novo
# Processing Record 4 of Set 14 | nioki
# Processing Record 5 of Set 14 | eidsvag
# Processing Record 6 of Set 14 | bemidji
# Processing Record 7 of Set 14 | road town
# Processing Record 8 of Set 14 | kalomo
# City not found. Skipping...
# Processing Record 9 of Set 14 | tazovskiy
# Processing Record 10 of Set 14 | bandarbeyla
# Processing Record 11 of Set 14 | gulshat
# City not found. Skipping...
# Processing Record 12 of Set 14 | bubaque
# Processing Record 13 of Set 14 | davenport
# Processing Record 14 of Set 14 | chabahar
# Processing Record 15 of Set 14 | mumford
# Processing Record 16 of Set 14 | sinnamary
# Processing Record 17 of Set 14 | turukhansk
# Processing Record 18 of Set 14 | mackay
# Processing Record 19 of Set 14 | sanchor
# Processing Record 20 of Set 14 | vozrozhdeniye
# Processing Record 21 of Set 14 | tiarei
# Processing Record 22 of Set 14 | emerald
# Processing Record 23 of Set 14 | neiafu
# Processing Record 24 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 25 of Set 14 | sheffield
# Processing Record 26 of Set 14 | asmar
# Processing Record 27 of Set 14 | fort-shevchenko
# Processing Record 28 of Set 14 | gizo
# Processing Record 29 of Set 14 | hunza
# City not found. Skipping...
# Processing Record 30 of Set 14 | guarapari
# Processing Record 31 of Set 14 | evensk
# Processing Record 32 of Set 14 | dzhusaly
# City not found. Skipping...
# Processing Record 33 of Set 14 | plettenberg bay
# Processing Record 34 of Set 14 | hearst
# Processing Record 35 of Set 14 | karratha
# Processing Record 36 of Set 14 | staunton
# Processing Record 37 of Set 14 | urla
# Processing Record 38 of Set 14 | anderson
# Processing Record 39 of Set 14 | corinth
# Processing Record 40 of Set 14 | yarmouth
# Processing Record 41 of Set 14 | pasighat
# Processing Record 42 of Set 14 | ulladulla
# Processing Record 43 of Set 14 | sao miguel
# Processing Record 44 of Set 14 | bonnyville
# Processing Record 45 of Set 14 | almaznyy
# Processing Record 46 of Set 14 | vanderhoof
# Processing Record 47 of Set 14 | camana
# Processing Record 48 of Set 14 | lashio
# Processing Record 49 of Set 14 | mecca
# Processing Record 50 of Set 14 | asau
# Processing Record 1 of Set 15 | gondar
# Processing Record 2 of Set 15 | bongandanga
# Processing Record 3 of Set 15 | saint-georges
# Processing Record 4 of Set 15 | barabinsk
# Processing Record 5 of Set 15 | tutoia
# Processing Record 6 of Set 15 | surt
# Processing Record 7 of Set 15 | witham
# Processing Record 8 of Set 15 | play cu
# City not found. Skipping...
# Processing Record 9 of Set 15 | ebolowa
# Processing Record 10 of Set 15 | coffs harbour
# Processing Record 11 of Set 15 | bakaly
# Processing Record 12 of Set 15 | espinosa
# Processing Record 13 of Set 15 | pisco
# Processing Record 14 of Set 15 | vanavara
# Processing Record 15 of Set 15 | baiyin
# Processing Record 16 of Set 15 | kirakira
# Processing Record 17 of Set 15 | palmer
# Processing Record 18 of Set 15 | vallenar
# Processing Record 19 of Set 15 | bar harbor
# Processing Record 20 of Set 15 | sao felix do xingu
# Processing Record 21 of Set 15 | zweibrucken
# Processing Record 22 of Set 15 | sakakah
# Processing Record 23 of Set 15 | nueva gorgona
# Processing Record 24 of Set 15 | nyagan
# Processing Record 25 of Set 15 | yerofey pavlovich
# Processing Record 26 of Set 15 | la romana
# Processing Record 27 of Set 15 | taksimo
# Processing Record 28 of Set 15 | ures
# Processing Record 29 of Set 15 | davila
# Processing Record 30 of Set 15 | maneadero
# Processing Record 31 of Set 15 | chernyshevskiy
# Processing Record 32 of Set 15 | dujuma
# City not found. Skipping...
# Processing Record 33 of Set 15 | talakan
# Processing Record 34 of Set 15 | armacao dos buzios
# City not found. Skipping...
# Processing Record 35 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 36 of Set 15 | la ligua
# Processing Record 37 of Set 15 | ruatoria
# City not found. Skipping...
# Processing Record 38 of Set 15 | alekseyevskaya
# Processing Record 39 of Set 15 | ballina
# Processing Record 40 of Set 15 | izhma
# Processing Record 41 of Set 15 | kerema
# Processing Record 42 of Set 15 | dunedin
# Processing Record 43 of Set 15 | nur
# Processing Record 44 of Set 15 | moron
# Processing Record 45 of Set 15 | salalah
# Processing Record 46 of Set 15 | belaya gora
# Processing Record 47 of Set 15 | pudur
# Processing Record 48 of Set 15 | bima
# Processing Record 49 of Set 15 | el retorno
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 688

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
challenge_city_data_df = pd.DataFrame(city_data)
challenge_city_data_df.head(10)
# Out:
#                City Country                 Date      Lat       Lng  Max Temp  \
# 0        Georgetown      MY  2021-08-07 22:07:59   5.4112  100.3354     81.90
# 1           Mataura      NZ  2021-08-07 22:07:26 -46.1927  168.8643     36.48
# 2      Port-Cartier      CA  2021-08-07 22:07:49  50.0334  -66.8654     69.93
# 3            Hobart      AU  2021-08-07 22:11:33 -42.8794  147.3294     36.27
# 4            Barrow      US  2021-08-07 22:11:33  71.2906 -156.7887     39.22
# 5           Ushuaia      AR  2021-08-07 22:11:34 -54.8000  -68.3000     29.86
# 6  Conselheiro Pena      BR  2021-08-07 22:11:34 -19.1722  -41.4722     67.42
# 7            Touros      BR  2021-08-07 22:11:34  -5.1989  -35.4608     77.90
# 8           Mattoon      US  2021-08-07 22:07:50  39.4831  -88.3728     87.60
# 9       Meadow Lake      US  2021-08-07 22:07:50  34.8014 -106.5436     97.68
#
#    Humidity  Cloudiness  Wind Speed Weather Description
# 0        86          20        4.61        thunderstorm
# 1        94         100        1.21     overcast clouds
# 2        59          79       10.51       broken clouds
# 3        88           0        1.99           clear sky
# 4        73          75        9.22       broken clouds
# 5        93          90       35.68                snow
# 6        70         100        9.48          light rain
# 7        77          73       17.87       broken clouds
# 8        65           1       11.50           clear sky
# 9        15          42       15.19    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
challenge_city_data_df.to_csv(output_data_file, index_label="City_ID")
